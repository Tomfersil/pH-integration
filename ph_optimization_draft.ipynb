# %% [markdown]
# ## Minimization of the loss function

# %% [markdown]
# **WARNING: development notebook**
#
# This notebook documents the work-in-progress implementation of `ph_loss` and its minimization through `ph_tilde_loss`. The final validation version is `ph_optimization.ipynb`.

# %% [markdown]
# After the definition of `Ph_data` objects, `Ph_consistency` objects and the loss function `ph_loss` (all contained in `ph_refine.py` with corresponding notebook `ph_refine.ipynb`), let's minimize this loss function.
#
# Notice we have renamed `ph_loss` as `ph_tilde_loss` to stress that it is not computed as the original definition $1/2\chi^2 + \mathrm{reg}$, rather including the minimization of the Gamma function; the `ph_loss` name is then used for defining the loss function defined at the beginning (before the introduction of Gamma)

# %%
import numpy as np

# %%
from ph_refine import load_ph_data, ph_gamma, ph_tilde_loss, ph_tilde_loss_and_grad

# %% [markdown]
# #### 1. load data and evaluate `ph_gamma` and `ph_loss`
# the evaluation of `ph_loss` without $\vec\lambda$ fixed requires a while due to the inner minimization of $\tilde\Gamma$

# %%
ph_vals = {'A3mer' : [3.00, 3.50, 4.00], 'A5mer' : [3.50, 4.00, 4.50]}

data = load_ph_data(path='Simulation-data', mol_name='A5mer', obs_names=['chi', 'eRMSD'],
                 ph_vals=ph_vals['A5mer'], ref_ph=4.50, g_exp=None, sigma_exp=None)

# %%
alphas = np.ones(len(data.g_exp))
ph_weights = np.vstack([data.pops[k] for k in data.pops.keys()])
lambdas = np.ones(len(data.g_exp))
exp_values = np.vstack((data.g_exp, data.sigma_exp))

args = (lambdas, data.legend_matrix, data.gs, exp_values.T, data.p0s, alphas, ph_weights)

ph_gamma(*args)
# Out:
# (Array(5.94410697, dtype=float64),
#  Array([1.11661429, 1.45532574], dtype=float64),
#  [Array([-0.58452639, -1.80951991, -1.34894436, ..., -0.84716311,
#          -0.41223641, -0.50194662], dtype=float64),
#   Array([-1.51657242, -0.56728817, -2.8114989 , ..., -1.53192192,
#          -0.16676047, -2.87485265], dtype=float64)])

# %%
from ph_refine import Manage_indices

table_lambdas = Manage_indices.flat_to_matrix(lambdas, data.legend_matrix)
table_lambdas = np.nan_to_num(table_lambdas)  # put nan to zero

print(table_lambdas.shape)
print(ph_weights.shape)
print(data.gs[1].shape)

j = 0

np.einsum('ki,i,tk->t', table_lambdas, ph_weights[:, j], data.gs[j])
# Out:
# (2, 3)
# (3, 2)
# (289236, 2)
# array([-0.58452639, -1.80951991, -1.34894436, ..., -0.84716311,
#        -0.41223641, -0.50194662])

# %%
log_pi_ref = np.log(data.pops[data.ref_ph])
log_pi_vec = +log_pi_ref

ph_tilde_loss(log_pi_vec, data)
# Out:
# Array(55.8743632, dtype=float64)

# %% [markdown]
# it takes a while due to the inner minimization of $\tilde\Gamma$, without it the function runs fast

# %%
from ph_refine import Lambdas

# %%
lambdas = Lambdas(np.zeros(len(data.g_exp)), True)

lambdas.value
# Out:
# array([0., 0., 0., 0., 0., 0.])

# %%
ph_tilde_loss(log_pi_vec, data, lambdas=lambdas)
# Out:
# Array(1.70267352, dtype=float64)

# %% [markdown]
# #### 2. now, minimize `ph_loss`

# %% [markdown]
# need to take the optimal value of lambdas, determined by the inner minimization of the Gamma function (inner to `ph_loss`)
#
# one good way to do this should be through a class `Lambdas` (using `global lambdas` is discouraged)

# %%
vars(lambdas)
# Out:
# {'value': array([0., 0., 0., 0., 0., 0.]), 'is_fixed': True}

# %%
lambdas = Lambdas(np.zeros(len(data.g_exp)), False)

# %%
ph_tilde_loss(log_pi_vec, data, lambdas)
# Out:
# Array(55.8743632, dtype=float64)

# %%
vars(lambdas)
# Out:
# {'value': array([ -177.62394998,   329.56229979,  -152.30862145,  3903.96499542,
#         -7237.01259758,  3333.03669435]),
#  'is_fixed': False}

# %%
ph_tilde_loss(log_pi_vec, data, lambdas)
# Out:
# Array(55.8743632, dtype=float64)

# %%
import jax

# %%
ph_tilde_loss_gradient_fun = jax.grad(ph_tilde_loss, argnums=0)

# %%
lambdas.is_fixed = True

ph_tilde_loss_gradient_fun(log_pi_vec, data, lambdas)
# Out:
# Array([ 29.49679298, -29.49679298], dtype=float64)

# %%
def ph_tilde_loss_and_grad(log_pi_vec, data, lambdas):

    assert not lambdas.is_fixed, 'error: lambdas is fixed'
    loss = ph_tilde_loss(log_pi_vec, data, lambdas)

    lambdas.is_fixed = True
    # in this way, the gradient is computed without looking at the derivative of lambdas w.r.t. log_pi_vec,
    # which is zero, since we are at the optimal lambdas for that log_pi_vec value
    
    grad = ph_tilde_loss_gradient_fun(log_pi_vec, data, lambdas)

    lambdas.is_fixed = False

    print(loss, grad)

    return loss, grad

# %%
lambdas = Lambdas(np.zeros(len(data.g_exp)), False)

ph_tilde_loss_and_grad(log_pi_vec, data, lambdas)
# Out:
# 55.87436319857597 [ 29.49679298 -29.49679298]
# (Array(55.8743632, dtype=float64),
#  Array([ 29.49679298, -29.49679298], dtype=float64))

# %%
vars(lambdas)
# Out:
# {'value': array([ -177.62394998,   329.56229979,  -152.30862145,  3903.96499542,
#         -7237.01259758,  3333.03669435]),
#  'is_fixed': False}

# %%
ph_tilde_loss_and_grad(log_pi_vec, data, lambdas)
# Out:
# 55.87436319857597 [ 29.49679298 -29.49679298]
# (Array(55.8743632, dtype=float64),
#  Array([ 29.49679298, -29.49679298], dtype=float64))

# %%
from scipy.optimize import minimize

# %%
lambdas = Lambdas(np.zeros(len(data.g_exp)), False)
args = (data, lambdas)

out = minimize(ph_tilde_loss_and_grad, log_pi_vec, args=args, method='BFGS', jac=True)
# Out:
# 55.87436319857597 [ 29.49679298 -29.49679298]
# 33.85204400336749 [ 4.45613287 -4.45613287]
# 33.01181566078389 [ 2.25069799 -2.25069799]
# 32.66367759223028 [ 0.50392341 -0.50392341]
# 32.64241010465675 [ 0.06859866 -0.06859866]
# 32.64191075456761 [ 0.01560513 -0.01560513]
# 32.64200836775343 [-0.016415  0.016415]
# 32.64197535006769 [-0.00403733  0.00403733]
# 32.64197431327751 [-0.00321056  0.00321056]
# 32.64197846976856 [-0.0009069  0.0009069]
# 32.64197846976794 [-0.00090704  0.00090704]
# 32.642008355775324 [-0.01619699  0.01619699]
# 32.641977649335395 [-0.00533416  0.00533416]
# 32.64197623262641 [-0.00413769  0.00413769]
# 32.64197569804521 [-0.00347341  0.00347341]
# 32.64197550066008 [-0.00254474  0.00254474]
# 32.641979349735244 [-0.00057643  0.00057643]
# 32.641979343493276 [-0.00024142  0.00024142]
# 32.64197933244341 [-0.00184707  0.00184707]
# 32.641979323188 [-0.00235238  0.00235238]
# 32.64197931777932 [-0.00272097  0.00272097]
# 32.64197931581267 [-0.00265607  0.00265607]
# 32.641979314147754 [-0.00284606  0.00284606]

# %%
out
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 32.64191075456761
#         x: [-1.371e+00 -1.896e-01]
#       nit: 5
#       jac: [ 1.561e-02 -1.561e-02]
#  hess_inv: [[ 5.556e-01  4.444e-01]
#             [ 4.444e-01  5.556e-01]]
#      nfev: 23
#      njev: 11

# %%
log_pi_vec
# Out:
# array([-0.35672622, -1.20385318])

# %%
pi_vec = np.exp(log_pi_vec)
pi_vec /= np.sum(pi_vec)

pi_vec
# Out:
# array([0.69996411, 0.30003589])

# %%
out.x
# Out:
# array([-1.37100997, -0.18956943])

# %%
x = out.x

x = np.exp(x)
x /= np.sum(x)

x
# Out:
# array([0.23479328, 0.76520672])

# %% [markdown]
# #### 3. check minimization
# is it true that the loss function has been minimized?
#
# let's define a function `ph_loss` for the loss function ($1/2 \chi^2 + \mathrm{reg}$) and verify we have minimized it

# %%
from ph_refine import compute_dkl, compute_ph_weights, ph_loss, Manage_indices, Lambdas, Ph_data
from bussilab import coretools

# %%
pi_vec = data.pops[data.ref_ph]
lambdas_vec = np.zeros(len(data.g_exp))

print(pi_vec)

out = ph_loss(lambdas=lambdas_vec, pis=pi_vec, data=data)#, alphas=np.ones(len(data.ns_prot)), alpha_pi=1)
# Out:
# [0.69996411 0.30003589]
# /tmp/ipykernel_4449/82421268.py:30: RuntimeWarning: divide by zero encountered in log
#   log_ps.append(np.log(data.p0s[j]) - logZs[j] - corrections[j])

# %%
out
# Out:
#          avs: array([[-1.54506178,  1.08278492],
#                      [-0.06397881,  1.35580914]])
#       avs_ph: array([[-0.34414487, -0.69275702, -1.10068373],
#                      [ 1.30416306,  1.23989957,  1.16470198]])
#  check_gamma: Array(29039.33324039, dtype=float64)
#         chi2: 58078.66648078074
#        dkl_p: [Array(-0., dtype=float64), Array(-2.22044605e-16, dtype=float64)]
#       dkl_pi: Array(0., dtype=float64)
#        gamma: Array(2.22044605e-16, dtype=float64)
#       log_ps: [Array([-17.95436422, -17.66668215, -16.20912477, ..., -13.82089607,
#                      -14.62867439, -14.26094961], dtype=float64), Array([-17.47963824, -18.1909128 , -16.62382244, ..., -13.7973674 ,
#                      -14.61146719, -14.04545789], dtype=float64)]
#         loss: Array(29039.33324039, dtype=float64)
#     rel_diff: array([[ -50.88746977, -112.22398641, -183.45089532],
#                      [   4.63868002,  -49.61151337,  -82.20619301]])

# %%
from scipy.optimize import minimize

# %%
lambdas = Lambdas(np.zeros(len(data.g_exp)), False)
args = (data, lambdas)
log_pi_vec = np.log(pi_vec)

mini = minimize(ph_tilde_loss_and_grad, log_pi_vec, args=args, method='BFGS', jac=True)
# Out:
# log pi vec:  [ 0.42356348 -0.42356348]
# -54.17168967641427 0.0
# log pi vec:  Traced<ConcreteArray([ 0.42356348 -0.42356348], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([ 0.42356348, -0.42356348], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f379c063dd0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f379574e2c0; to 'JaxprTracer' at 0x7f379574e950>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6e708a10>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-54.17168967641427, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-54.17168968, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679050>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795713860; to 'JaxprTracer' at 0x7f3795713770>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6ed87500>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.0, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0., dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679a20>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37956a1a40; to 'JaxprTracer' at 0x7f37956a1ae0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72b4bfb0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 54.17168967641427 [ 28.71997684 -28.71997684]
# log pi vec:  [-0.29061437  0.29061437]
# -31.804130366888224 0.24739372538375726
# log pi vec:  Traced<ConcreteArray([-0.29061437  0.29061437], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-0.29061437,  0.29061437], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956796e0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37956b6d60; to 'JaxprTracer' at 0x7f37956b64a0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b73ffed00>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-31.804130366888224, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-31.80413037, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956199f0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379551e130; to 'JaxprTracer' at 0x7f379551e0e0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74229fd0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.24739372538375726, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.24739373, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619c20>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795524540; to 'JaxprTracer' at 0x7f37955244f0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74211f00>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 32.05152409227198 [ 5.39682271 -5.39682271]
# log pi vec:  [-0.45587037  0.45587037]
# -30.30618158848048 0.36191037959743194
# log pi vec:  Traced<ConcreteArray([-0.45587037  0.45587037], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-0.45587037,  0.45587037], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679030>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37956f17c0; to 'JaxprTracer' at 0x7f37956f1360>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b740b04d0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-30.30618158848048, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-30.30618159, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619030>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795524a40; to 'JaxprTracer' at 0x7f3795524090>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b723459b0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.36191037959743194, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.36191038, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619740>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795533540; to 'JaxprTracer' at 0x7f37955334f0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b7412b6d0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 30.668091968077913 [ 3.14445356 -3.14445356]
# log pi vec:  [-0.68657848  0.68657848]
# -29.149606783126288 0.5293261191706525
# log pi vec:  Traced<ConcreteArray([-0.68657848  0.68657848], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-0.68657848,  0.68657848], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f379577ae50>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f379573d7c0; to 'JaxprTracer' at 0x7f379573d810>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741af350>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-29.149606783126288, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-29.14960678, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619830>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379579e900; to 'JaxprTracer' at 0x7f379579e8b0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b7413ac40>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.5293261191706525, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.52932612, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956796e0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957a4f40; to 'JaxprTracer' at 0x7f37957a4ef0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74244150>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.67893290229694 [ 1.34261569 -1.34261569]
# log pi vec:  [-0.85848758  0.85848758]
# -28.71153042478165 0.648257231248673
# log pi vec:  Traced<ConcreteArray([-0.85848758  0.85848758], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-0.85848758,  0.85848758], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619ef0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37957504f0; to 'JaxprTracer' at 0x7f3795750f90>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74200580>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.71153042478165, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.71153042, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956195f0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795785220; to 'JaxprTracer' at 0x7f37957851d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b7419b360>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.648257231248673, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.64825723, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956798d0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795787630; to 'JaxprTracer' at 0x7f37957875e0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741caca0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.359787656030324 [ 0.56105512 -0.56105512]
# log pi vec:  [-0.98189514  0.98189514]
# -28.552074351073585 0.7266351221437874
# log pi vec:  Traced<ConcreteArray([-0.98189514  0.98189514], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-0.98189514,  0.98189514], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679f00>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37956f1f40; to 'JaxprTracer' at 0x7f37956f1310>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6f3ad490>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.552074351073585, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.55207435, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619fe0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957862c0; to 'JaxprTracer' at 0x7f3795786270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6f4c37e0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7266351221437874, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.72663512, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956197b0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379551e6d0; to 'JaxprTracer' at 0x7f379551e680>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741e7a90>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.278709473217372 [ 0.09693135 -0.09693135]
# log pi vec:  [-1.00766857  1.00766857]
# -28.534171240441815 0.7421095869867839
# log pi vec:  Traced<ConcreteArray([-1.00766857  1.00766857], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00766857,  1.00766857], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679e40>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f379574ebd0; to 'JaxprTracer' at 0x7f379574eea0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b740cb110>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.534171240441815, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53417124, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619fc0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957a62c0; to 'JaxprTracer' at 0x7f37957a6270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b729f7d30>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7421095869867839, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74210959, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f379c063c40>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955336d0; to 'JaxprTracer' at 0x7f3795533680>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b7413b210>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.2762808274286 [-0.00342622  0.00342622]
# log pi vec:  [-1.00678866  1.00678866]
# -28.53469069509712 0.7415866554684821
# log pi vec:  Traced<ConcreteArray([-1.00678866  1.00678866], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00678866,  1.00678866], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679e40>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37955ba4a0; to 'JaxprTracer' at 0x7f37955ba310>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a0eaf0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53469069509712, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.5346907, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619af0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955432c0; to 'JaxprTracer' at 0x7f3795543270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a24220>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7415866554684821, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74158666, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619b30>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955406d0; to 'JaxprTracer' at 0x7f3795540680>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a2d270>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.2762773505656 [-0.0005664  0.0005664]
# log pi vec:  [-1.00661439  1.00661439]
# -28.534794144285623 0.7414830406219095
# log pi vec:  Traced<ConcreteArray([-1.00661439  1.00661439], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661439,  1.00661439], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619bf0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37955c47c0; to 'JaxprTracer' at 0x7f37955c44a0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a2a140>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.534794144285623, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479414, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619fb0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379552d2c0; to 'JaxprTracer' at 0x7f379552d270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a510c0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830406219095, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148304, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679e30>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955376d0; to 'JaxprTracer' at 0x7f3795537680>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a4b210>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.27627718490753 [-0.00041609  0.00041609]
# log pi vec:  [-1.00621228  1.00621228]
# -28.53503385543442 0.7412439047558278
# log pi vec:  Traced<ConcreteArray([-1.00621228  1.00621228], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00621228,  1.00621228], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619e10>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37955bab30; to 'JaxprTracer' at 0x7f37955bacc0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a54660>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53503385543442, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53503386, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619fd0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955432c0; to 'JaxprTracer' at 0x7f3795543270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a7d3a0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7412439047558278, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.7412439, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679de0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795549720; to 'JaxprTracer' at 0x7f37955496d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a843d0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277760190247 [ 0.00128917 -0.00128917]
# log pi vec:  [-1.0065614  1.0065614]
# -28.534825769872697 0.7414515330615015
# log pi vec:  Traced<ConcreteArray([-1.0065614  1.0065614], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.0065614,  1.0065614], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619a90>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37957934a0; to 'JaxprTracer' at 0x7f3795793450>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a5dd60>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.534825769872697, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53482577, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619fb0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379554b310; to 'JaxprTracer' at 0x7f379554b2c0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a907e0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414515330615015, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74145153, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679ea0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f379554e720; to 'JaxprTracer' at 0x7f379554e6d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72abacd0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277302934197 [ 0.00020054 -0.00020054]
# log pi vec:  [-1.00661147  1.00661147]
# -28.53479599672665 0.7414813021981418
# log pi vec:  Traced<ConcreteArray([-1.00661147  1.00661147], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661147,  1.00661147], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619bf0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37955afa90; to 'JaxprTracer' at 0x7f37955af860>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741fc950>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53479599672665, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.534796, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619bd0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795540310; to 'JaxprTracer' at 0x7f37955402c0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6f4dfd10>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414813021981418, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.7414813, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956793a0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795545720; to 'JaxprTracer' at 0x7f37955456d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b740e6050>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277298924793 [-3.88133806e-06  3.88133806e-06]
# log pi vec:  [-1.00661438  1.00661438]
# -28.5347942642809 0.7414830345048544
# log pi vec:  Traced<ConcreteArray([-1.00661438  1.00661438], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661438,  1.00661438], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619990>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37956f1f40; to 'JaxprTracer' at 0x7f37956f1bd0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741b6390>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.5347942642809, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479426, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619d10>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795556310; to 'JaxprTracer' at 0x7f37955562c0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74221f90>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830345048544, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148303, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679c70>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795547720; to 'JaxprTracer' at 0x7f37955476d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b7418ce10>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277298785754 [ 5.34766052e-05 -5.34766052e-05]
# log pi vec:  [-1.00661439  1.00661439]
# -28.53479425816266 0.7414830406218331
# log pi vec:  Traced<ConcreteArray([-1.00661439  1.00661439], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661439,  1.00661439], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619e20>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37957a4e50; to 'JaxprTracer' at 0x7f37957504f0>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6f32eb90>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53479425816266, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479426, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619b40>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795556310; to 'JaxprTracer' at 0x7f37955562c0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741b3f10>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830406218331, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148304, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679e70>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795555720; to 'JaxprTracer' at 0x7f37955556d0>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74175310>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277298784493 [ 5.37600588e-05 -5.37600588e-05]
# log pi vec:  [-1.00661439  1.00661439]
# -28.534794258161813 0.7414830406219095
# log pi vec:  Traced<ConcreteArray([-1.00661439  1.00661439], dtype=float64)>with<JVPTrace(level=2/0)> with
# ...
# Traced<ConcreteArray(-28.534794458902176, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479446, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37956197a0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795785bd0; to 'JaxprTracer' at 0x7f3795785b80>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b741c0e50>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414828876208782, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148289, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f379577a810>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957b42c0; to 'JaxprTracer' at 0x7f37957b4270>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6e2da080>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277346523056 [ 0.000224 -0.000224]
# log pi vec:  [-1.00661426  1.00661426]
# -28.534794382342625 0.7414829641213978
# log pi vec:  Traced<ConcreteArray([-1.00661426  1.00661426], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661426,  1.00661426], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679e70>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f3795615c20; to 'JaxprTracer' at 0x7f37957efb80>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6ee58710>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.534794382342625, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479438, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619d40>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957b40e0; to 'JaxprTracer' at 0x7f37957b4090>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b726d3670>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414829641213978, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148296, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619af0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795792860; to 'JaxprTracer' at 0x7f3795792810>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a20010>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277346464024 [ 0.00022755 -0.00022755]
# log pi vec:  [-1.00661432  1.00661432]
# -28.53479434406343 0.7414830023716551
# log pi vec:  Traced<ConcreteArray([-1.00661432  1.00661432], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661432,  1.00661432], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679090>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f379573de00; to 'JaxprTracer' at 0x7f379574c720>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6f2e5370>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53479434406343, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479434, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619910>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957b4c20; to 'JaxprTracer' at 0x7f37957b4c70>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b73ffae80>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830023716551, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.741483, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619ca0>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795792540; to 'JaxprTracer' at 0x7f3795792590>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b72a345d0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277346435087 [ 0.00022932 -0.00022932]
# log pi vec:  [-1.00661436  1.00661436]
# -28.534794324923496 0.7414830214967827
# log pi vec:  Traced<ConcreteArray([-1.00661436  1.00661436], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661436,  1.00661436], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679d20>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37956b1310; to 'JaxprTracer' at 0x7f37956b1270>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b6fcd8fa0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.534794324923496, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479432, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619af0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957850e0; to 'JaxprTracer' at 0x7f3795785b80>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b73ffae80>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830214967827, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148302, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f37957a6030>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37957922c0; to 'JaxprTracer' at 0x7f3795792950>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b740dc410>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.27627734642028 [ 0.0002302 -0.0002302]
# log pi vec:  [-1.00661437  1.00661437]
# -28.53479431535317 0.7414830310593462
# log pi vec:  Traced<ConcreteArray([-1.00661437  1.00661437], dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array([-1.00661437,  1.00661437], dtype=float64)
#   tangent = Traced<ShapedArray(float64[2])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[2]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795679d10>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>, Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>), out_tracer_refs=[<weakref at 0x7f37955c1e00; to 'JaxprTracer' at 0x7f37957b6400>], out_avals=[ShapedArray(float64[2])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2] b:f64[]. let c:f64[2] = sub a b in (c,) }, 'in_shardings': (UnspecifiedValue, UnspecifiedValue), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None, None), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False, False), 'name': 'subtract', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b73fa23f0>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# Traced<ConcreteArray(-28.53479431535317, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(-28.53479432, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f3795619ca0>, in_tracers=(Traced<ShapedArray(float64[]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f37955407c0; to 'JaxprTracer' at 0x7f3795540d10>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[]. let  in (a,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': 'add', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74079c40>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False)) Traced<ConcreteArray(0.7414830310593462, dtype=float64)>with<JVPTrace(level=2/0)> with
#   primal = Array(0.74148303, dtype=float64)
#   tangent = Traced<ShapedArray(float64[])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float64[]), None)
#     recipe = JaxprEqnRecipe(eqn_id=<object object at 0x7f379577d030>, in_tracers=(Traced<ShapedArray(float64[2]):JaxprTrace(level=1/0)>,), out_tracer_refs=[<weakref at 0x7f3795792270; to 'JaxprTracer' at 0x7f3795792680>], out_avals=[ShapedArray(float64[])], primitive=pjit, params={'jaxpr': { lambda ; a:f64[2]. let b:f64[] = reduce_sum[axes=(0,)] a in (b,) }, 'in_shardings': (UnspecifiedValue,), 'out_shardings': (UnspecifiedValue,), 'in_layouts': (None,), 'out_layouts': (None,), 'resource_env': None, 'donated_invars': (False,), 'name': '_reduce_sum', 'keep_unused': False, 'inline': True}, effects=set(), source_info=SourceInfo(traceback=<jaxlib.xla_extension.Traceback object at 0x558b74035040>, name_stack=NameStack(stack=(Transform(name='jvp'),))), ctx=JaxprEqnContext(compute_type=None,threefry_partitionable=False))
# 29.276277346412517 [ 0.00023065 -0.00023065]

# %%
mini
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 29.27627718490753
#         x: [-1.787e+00  2.263e-01]
#       nit: 8
#       jac: [-4.161e-04  4.161e-04]
#  hess_inv: [[ 1.080e+00 -7.971e-02]
#             [-7.971e-02  1.080e+00]]
#      nfev: 27
#      njev: 15

# %%
lambdas_new = lambdas.value

pi_new = np.exp(mini.x)
print(np.sum(pi_new))

pi_new
# Out:
# 1.4214606218749182
# array([0.16747786, 1.25398276])

# %%
ph_loss(lambdas_new, pi_new, data)#, alphas=np.ones(len(data.ns_prot)), alpha_pi=1)
# Out:
# /tmp/ipykernel_4449/82421268.py:30: RuntimeWarning: divide by zero encountered in log
#   log_ps.append(np.log(data.p0s[j]) - logZs[j] - corrections[j])
#          avs: array([[-1.11207242,  0.94284939],
#                      [-0.10467443,  1.30692033]])
#       avs_ph: array([[-0.11795159, -0.14549711, -0.22336704],
#                      [ 1.302122  ,  1.29216712,  1.26402514]])
#  check_gamma: Array(2.95029248e-06, dtype=float64)
#         chi2: 56.66819808390798
#        dkl_p: [Array(0.17563596, dtype=float64), Array(0.02506225, dtype=float64)]
#       dkl_pi: Array(1.55389525, dtype=float64)
#        gamma: Array(-28.53479431, dtype=float64)
#       log_ps: [Array([-17.36381074, -17.48875313, -16.07984416, ..., -14.78974885,
#                      -15.5231716 , -15.15169798], dtype=float64), Array([-17.041346  , -17.90600057, -15.98036985, ..., -14.02722229,
#                      -14.81036703, -14.40183795], dtype=float64)]
#         loss: Array(30.08869251, dtype=float64)
#     rel_diff: array([[-3.32420465,  4.45055373, -1.20524439],
#                      [ 2.851467  , -3.88189297,  1.07603995]])

# %%
vars(lambdas)
# Out:
# {'value': array([ -698.8688273 ,   949.07000085,  -250.54148316,  2495.45700567,
#         -3395.7537753 ,   903.01587223]),
#  'is_fixed': False}

# %%
lambdas.is_fixed = True

ph_tilde_loss(np.log(pi_new), data, lambdas)
# Out:
# log pi vec:  [-1.00661439  1.00661439]
# -28.534794305782917 0.7414830406219095
# Array(29.27627735, dtype=float64)

# %%
lambdas.is_fixed = False

ph_tilde_loss(np.log(pi_new), data, lambdas)
# Out:
# log pi vec:  [-1.00661439  1.00661439]
# -28.534794305782967 0.7414830406219095
# Array(29.27627735, dtype=float64)

# %%
my_pi = +pi_new
log_pi_ref = np.log(data.pops[data.ref_ph])

# %%
my_pi
# Out:
# array([0.11782097, 0.88217903])

# %%
log_pi_new = np.log(my_pi)

log_pi_new -= np.mean(log_pi_new)
pi_new = np.exp(log_pi_new - np.max(log_pi_new))
pi_new /= np.sum(pi_new)

print(pi_new)

dkl = np.sum(pi_new*(np.log(pi_new) - log_pi_ref))

dkl
# Out:
# [0.11782097 0.88217903]
# 0.7414830406219095

# %%
dkl = np.sum(pi_new*(np.log(pi_new) - np.log(data.pops[data.ref_ph])))

dkl
# Out:
# 0.7414830406219095

# %%
out = ph_loss(lambdas.value, pi_new, data)

out
# Out:
# /tmp/ipykernel_4449/82421268.py:30: RuntimeWarning: divide by zero encountered in log
#   log_ps.append(np.log(data.p0s[j]) - logZs[j] - corrections[j])
#          avs: array([[-1.11207242,  0.94284939],
#                      [-0.10467443,  1.30692033]])
#       avs_ph: array([[-0.11795159, -0.14549711, -0.22336704],
#                      [ 1.302122  ,  1.29216712,  1.26402514]])
#  check_gamma: Array(2.95029218e-06, dtype=float64)
#         chi2: 56.66819808390622
#        dkl_p: [Array(0.17563596, dtype=float64), Array(0.02506225, dtype=float64)]
#       dkl_pi: Array(0.74148304, dtype=float64)
#        gamma: Array(-28.53479431, dtype=float64)
#       log_ps: [Array([-17.36381074, -17.48875313, -16.07984416, ..., -14.78974885,
#                      -15.5231716 , -15.15169798], dtype=float64), Array([-17.041346  , -17.90600057, -15.98036985, ..., -14.02722229,
#                      -14.81036703, -14.40183795], dtype=float64)]
#         loss: Array(29.2762803, dtype=float64)
#     rel_diff: array([[-3.32420465,  4.45055373, -1.20524439],
#                      [ 2.851467  , -3.88189297,  1.07603995]])

# %%
log_pi_new = np.log(pi_new)
log_pi_new -= np.mean(log_pi_new)

log_pi_ref = np.log(data.pops[data.ref_ph])

np.sum(np.exp(log_pi_new)*(log_pi_new - log_pi_ref))
# Out:
# 5.811044910770843

# %%
np.sum(np.exp(log_pi_vec)*(log_pi_vec - log_pi_ref))
